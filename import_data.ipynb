# %% [markdown]
# __Import Data__

# %%
import pandas as pd

# %%
data = pd.read_csv('Customer-Churn.csv')

# %%
data.shape
data.head()
# Out:
#    Maior65Anos Conjuge Dependentes  MesesDeContrato TelefoneFixo  \
# 0            0     Sim         Nao                1          Nao
# 1            0     Nao         Nao               34          Sim
# 2            0     Nao         Nao                2          Sim
# 3            0     Nao         Nao               45          Nao
# 4            0     Nao         Nao                2          Sim
#
#   VariasLinhasTelefonicas ServicoDeInternet SegurancaOnline BackupOnline  \
# 0    SemServicoTelefonico               DSL             Nao          Sim
# 1                     Nao               DSL             Sim          Nao
# 2                     Nao               DSL             Sim          Sim
# 3    SemServicoTelefonico               DSL             Sim          Nao
# 4                     Nao       FibraOptica             Nao          Nao
#
#   SeguroNoDispositivo SuporteTecnico TVaCabo StreamingDeFilmes TipoDeContrato  \
# ...

# %%
translate_dictionary = {'Sim': 1, 'Nao': 0}

n_data = data[['Conjuge', 'Dependentes', 'TelefoneFixo', 'PagamentoOnline', 'Churn']]. replace(translate_dictionary)
n_data.head()
# Out:
#    Conjuge  Dependentes  TelefoneFixo  PagamentoOnline  Churn
# 0        1            0             0                1      0
# 1        0            0             1                0      0
# 2        0            0             1                1      1
# 3        0            0             0                0      0
# 4        0            0             1                1      1

# %%
data_dummie = pd.get_dummies(data.drop(['Conjuge', 'Dependentes', 'TeefoneFixo', 'PagamentoOnline', 'Churn'], axis=1))
final_data = pd.concat([n_data, data_dummie], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/ny/l547_r6n237_5qvjprhgmqkm0000gn/T/ipykernel_2636/1855719083.py in <module>
# ----> 1 data_dummie = pd.get_dummies(data.drop(['Conjuge', 'Dependentes', 'TeefoneFixo', 'PagamentoOnline', 'Churn'], axis=1))
#       2 final_data = pd.concat([n_data, data_dummie], axis=1)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
# ...
